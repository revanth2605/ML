# %% [markdown]
# <a href="https://colab.research.google.com/github/revanth2605/ML/blob/main/AP23110010566_Data_vizulization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
import os
os.environ['KAGGLE_USERNAME'] = 'revanth261205'
os.environ['KAGGLE_KEY'] = '24a59c2b135f9218c788af95ed4a2ee1'

# %%
# !kaggle datasets download -d uciml/breast-cancer-wisconsin-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data
# License(s): CC-BY-NC-SA-4.0
# ...
#   0% 0.00/48.6k [00:00<?, ?B/s]
# 100% 48.6k/48.6k [00:00<00:00, 134MB/s]

# %%
# !unzip breast-cancer-wisconsin-data.zip
# Out:
# Archive:  breast-cancer-wisconsin-data.zip
#   inflating: data.csv

# %%
df = pd.read_csv('/content/data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
x_val = [1, 2, 3, 4, 5]
y_val = [2, 4, 5, 4, 5]

# Create a basic line plot
plt.plot(x_val, y_val)

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Basic Line Plot')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=df)
plt.title('Distribution of Diagnosis (M=Malignant, B=Benign)')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
# Univariate analysis of the 'perimeter_mean' column
plt.figure(figsize=(8, 6))
sns.histplot(x='perimeter_mean', data=df, kde=True)
plt.title('Distribution of Perimeter Mean')
plt.xlabel('Perimeter Mean')
plt.ylabel('Frequency')
plt.show()

# %%
# Univariate analysis of the 'texture_mean' column
plt.figure(figsize=(8, 6))
sns.histplot(x='texture_mean', data=df, kde=True)
plt.title('Distribution of Texture Mean')
plt.xlabel('Texture Mean')
plt.ylabel('Frequency')
plt.show()

# %%
# Univariate analysis of the 'radius_mean' column
plt.figure(figsize=(8, 6))
sns.histplot(x='radius_mean', data=df, kde=True)
plt.title('Distribution of Radius Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a pie chart of the 'diagnosis' column
diagnosis_counts = df['diagnosis'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(diagnosis_counts, labels=diagnosis_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Diagnosis (M=Malignant, B=Benign)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(x='radius_mean', data=df, fill=True)
plt.title('Kernel Density Estimate of Radius Mean')
plt.xlabel('Radius Mean')
plt.ylabel('Density')
plt.show()
